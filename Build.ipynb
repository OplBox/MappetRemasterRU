# %% [markdown]
# # Сборка MappetRemasterRU (через скрипт)
#
# Этот ноутбук Google Colab поможет вам собрать проект MappetRemasterRU и его документацию. Он использует единый shell-скрипт для большей надежности.

# %% [markdown]
# ## 1. Клонирование репозитория
#
# Эта ячейка скачает ваш репозиторий.

# %%
import os
repository_url = 'https://github.com/OplBox/MappetRemasterRU.git' #@param {type:"string"}
os.chdir('/content')
# !rm -rf MappetRemasterRU
# !git clone {repository_url}
os.chdir('/content/MappetRemasterRU')

# %% [markdown]
# ## 2. Запуск скрипта сборки
#
# Эта ячейка запустит единый скрипт `build.sh`, который выполнит все шаги сборки. Это может занять несколько минут.

# %%
# !chmod +x build.sh
# !./build.sh

# %% [markdown]
# ## 3. Результаты
#
# Сборка завершена! Вы можете найти результаты в следующих директориях:
#
# *   **Собранный мод:** `build/libs/mappet-0.7.jar`
# *   **Javadoc документация:** `build/docs/javadoc`
# *   **JSON документация:** `src/main/resources/assets/mappet/docs.json`
#
# Вы можете скачать эти файлы из файлового менеджера слева.
